# %% [markdown]
# Typecasting all Datatypes to Integer

# %%
int(3.5)
# Out:
# 3

# %%
int(True)
# Out:
# 1

# %%
int (False)
# Out:
# 0

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int(2.3, 5.6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 int(2.3, 5.6)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int('10')
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
int('23.4')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 int('23.4')
#
# ValueError: invalid literal for int() with base 10: '23.4'

# %% [markdown]
# Typecasting all Datatypes to float

# %%
float(23)
# Out:
# 23.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float(2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 float(2,3)
#
# TypeError: float expected at most 1 argument, got 2

# %%
float('23')
# Out:
# 23.0

# %%
float('23.4')
# Out:
# 23.4

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %% [markdown]
# Typecasting all Datatypes to bool

# %%
bool(2)
# Out:
# True

# %%
bool(2.3)
# Out:
# True

# %%
bool(1+2j)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool()
# Out:
# False

# %%
bool('10')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %% [markdown]
# Typecasting all Datatypes to complex

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 complex(10,20,30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2.3)
# Out:
# (2.3+0j)

# %%
complex(2.3,4.5)
# Out:
# (2.3+4.5j)

# %%
complex(True,False)
# Out:
# (1+0j)

# %%
complex(False,False)
# Out:
# 0j

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('10','20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 complex('10','20')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(10,'20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 complex(10,'20')
#
# TypeError: complex() second arg can't be a string

# %% [markdown]
# Typecasting all Datatypes to string

# %%
str(20)
# Out:
# '20'

# %%
str(2.3)
# Out:
# '2.3'

# %%
str(True)
# Out:
# 'True'

# %%
str(1+2j)
# Out:
# '(1+2j)'

# %% [markdown]
# Python Operators
#
# 1. Arithmetic Operator

# %%
x1,y1=10,5

# %%
x1+y1
# Out:
# 15

# %%
x1*y1
# Out:
# 50

# %%
x1/y1
# Out:
# 2.0

# %%
x1//y1
# Out:
# 2

# %%
x1%y1
# Out:
# 0

# %%
x1**y1
# Out:
# 100000

# %%
x2=3
y2=3

# %%
x2**y2
# Out:
# 27

# %% [markdown]
# 2. Assignment Operator

# %%
x=2

# %%
x
# Out:
# 2

# %%
x=x+2
x
# Out:
# 4

# %%
x+=2

# %%
x
# Out:
# 6

# %%
x+=2
x
# Out:
# 8

# %%
x*=2
x
# Out:
# 16

# %%
x-=2

# %%
x
# Out:
# 14

# %%
x//=2
x
# Out:
# 7

# %%
x/=2
x
# Out:
# 3.5

# %% [markdown]
# Relational Operator

# %%
a=5
b=6

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
b=5

# %%
a==b
# Out:
# True

# %%
a
# Out:
# 5

# %%
b
# Out:
# 5

# %%
a>b
# Out:
# False

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# True

# %% [markdown]
# Logical Operator

# %%
a=5
b=4

# %%
a<8 and b<5
# Out:
# True

# %%
a<8 and b<2
# Out:
# False

# %%
a<8 or b<2
# Out:
# True

# %%
a>8 or b<2
# Out:
# False

# %%
x=False

# %%
x
# Out:
# False

# %%
not x
# Out:
# True

# %%
x
# Out:
# False

# %% [markdown]
# Unary Operator

# %%
n=7

# %%
n
# Out:
# 7

# %%
m=-(n)

# %%
m
# Out:
# -7

# %%
-n
# Out:
# -7

# %% [markdown]
# Number System and Bitwise Operators

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
bin(30)
# Out:
# '0b11110'

# %%
int(0b11110)
# Out:
# 30

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
bin(7)
# Out:
# '0b111'

# %%
int(0b111)
# Out:
# 7

# %%
hex(25)
# Out:
# '0x19'

# %%
int(0x19)
# Out:
# 25

# %%
print(hex(1))
# Out:
# 0x1

# %%
print(hex(2))
# Out:
# 0x2

# %%
print(hex(2))
print(hex(3))
print(hex(4))
print(hex(7))
print(hex(8))
print(hex(9))
print(hex(10))
# Out:
# 0x2
# 0x3
# 0x4
# 0x7
# 0x8
# 0x9
# 0xa

# %%
print(hex(10))
print(hex(11))
print(hex(12)
print(hex(13))
print(hex(14))
print(hex(15))
print(hex(16))
# Out:
#   Cell In[15], line 3
#     print(hex(12)
#          ^
# SyntaxError: '(' was never closed

# %%
print(hex(10))
print(hex(11))
print(hex(12))
print(hex(13))
print(hex(14))
print(hex(15))
print(hex(16))
# Out:
# 0xa
# 0xb
# 0xc
# 0xd
# 0xe
# 0xf
# 0x10

# %%
hex(25)
# Out:
# '0x19'

# %% [markdown]
# Bitwise Operator
#
# 1. Complement

# %%
~12
# Out:
# -13

# %%
~45
# Out:
# -46

# %%
~9
# Out:
# -10

# %% [markdown]
# 2. Bitwise And Operator, Bitwise Or Operator

# %%
12 & 13
# Out:
# 12

# %%
10 & 12
# Out:
# 8

# %%
12 | 13
# Out:
# 13

# %%
1 & 0
# Out:
# 0

# %%
1 | 0
# Out:
# 1

# %% [markdown]
# Xor

# %%
12 ^ 13
# Out:
# 1

# %%
25 ^ 30
# Out:
# 7

# %%
print(bin(25))
print(bin(30))
# Out:
# 0b11001
# 0b11110

# %% [markdown]
# Left Shift <<

# %%
12 << 2
# Out:
# 48

# %%
13 << 1
# Out:
# 26

# %%
Right Shift >>

# %%
12 >> 2
# Out:
# 3

# %%
12 >> 1
# Out:
# 6

# %%
12 >> 3
# Out:
# 1

# %%
first_name = 'NAVANEETHA'
last_name = 'CHERUKU'
country = 'HYD'
city = 'TELENGANA'
age = 36
is_married = True

# %%
print('First Name:',first_name)
# Out:
# First Name: NAVANEETHA

# %%
print ('Last Name:',last_name)
# Out:
# Last Name: CHERUKU

# %%
print('Country:',country)
# Out:
# Country: HYD

# %%
print('First Name:',first_name)
print ('Last Name:',last_name)
print('Country:',country)
# Out:
# First Name: NAVANEETHA
# Last Name: CHERUKU
# Country: HYD

# %%
first_name, last_name, country, age, is_married = 'navaneetha', 'cheruku', 'Hyd', 36, True

# %%
print('First Name:',first_name)
print ('Last Name:',last_name)
print('Country:',country)
print('Age:',age)
print('Is married:',is_married)
# Out:
# First Name: navaneetha
# Last Name: cheruku
# Country: Hyd
# Age: 36
# Is married: True

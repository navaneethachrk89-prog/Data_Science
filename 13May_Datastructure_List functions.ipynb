# %% [markdown]
# 12May_Python Datastructure_List

# %% [markdown]
# - List
# - Tuple
# - Set
# - dict
# - range

# %% [markdown]
# LIST

# %%
l=[]

# %%
l
# Out:
# []

# %%
l1=[10,20,30]

# %%
l1
# Out:
# [10, 20, 30]

# %%
l1.append(40)
l1.append(50)
l1.append(60)
l1.append(10)

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10]

# %%
len(l1)
# Out:
# 7

# %%
l1.append(70,80)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 l1.append(70,80)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l1

# %%
l1.append(['a','b','c'])

# %%
l1

# %%
l2=[34,5.3,'navaneetha',1+2j,True]

# %%
l2

# %%
print(l)
print(l1)
print(l2)

# %%
print(len(l))
print(len(l1))
print(len(l2))

# %%
print(id(l))
print(id(l1))
print(id(l2))

# %%
print(type(l))
print(type(l1))
print(type(l2))

# %%
l1

# %%
# list membership

# %%
10 in l1

# %%
['a','b','c'] in l1

# %%
100 in l1

# %%
l2

# %%
l3

# %%
l3=l2.copy()

# %%
l3

# %%
print(id(l2))
print(id(l3))

# %%
print(l)
print(l1)
print(l2)
print(l3)

# %%
l3

# %%
len(l3)

# %%
l3.clear()

# %%
l3

# %%
del l3

# %%
l3

# %%
l2.count(5.3)

# %%
l1.count(10)

# %%
l1[:]

# %%
l1[-1]

# %%
l1[100]

# %%
l1[4:]

# %%
l1[3:-1]

# %%
l1[0:10:3]

# %%
l1[::1]

# %%
l1[::2]

# %%
l1[::3]

# %%
l1[::-1]

# %%
l1[::-2]

# %%
l1[::-3]
# Out:
# [10, 40, 10]

# %%
l1[4:-3]
# Out:
# []

# %%
print(l)
print(l1)
print(l2)
# Out:
# []
# [10, 20, 30, 40, 50, 60, 10]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 print(l)
#       2 print(l1)
# ----> 3 print(l2)
#
# NameError: name 'l2' is not defined

# %%
l2=[34,5.3,'navaneetha',(1+2j),True]

# %%
print(l)
print(l1)
print(l2)
# Out:
# []
# [10, 20, 30, 40, 50, 60, 10]
# [34, 5.3, 'navaneetha', (1+2j), True]

# %%
l1.append(['a','b','c'])

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
print(l)
print(l1)
print(l2)
# Out:
# []
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]
# [34, 5.3, 'navaneetha', (1+2j), True]

# %%
l1[0]
# Out:
# 10

# %%
l1[0]=100

# %%
l1
# Out:
# [100, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[-1]='navaneetha'

# %%
l1
# Out:
# [100, 20, 30, 40, 50, 60, 10, 'navaneetha']

# %%
print(l)
print(l1)
print(l2)
# Out:
# []
# [100, 20, 30, 40, 50, 60, 10, 'navaneetha']
# [34, 5.3, 'navaneetha', (1+2j), True]

# %%
l.extend(l2)

# %%
print(l)
print(l1)
print(l2)
# Out:
# [34, 5.3, 'navaneetha', (1+2j), True]
# [100, 20, 30, 40, 50, 60, 10, 'navaneetha']
# [34, 5.3, 'navaneetha', (1+2j), True]

# %%
l.extend(l1)

# %%
print(l)
print(l1)
print(l2)
# Out:
# [34, 5.3, 'navaneetha', (1+2j), True, 100, 20, 30, 40, 50, 60, 10, 'navaneetha']
# [100, 20, 30, 40, 50, 60, 10, 'navaneetha']
# [34, 5.3, 'navaneetha', (1+2j), True]

# %%
l.index('navaneetha')
# Out:
# 2

# %%
l1
# Out:
# [100, 20, 30, 40, 50, 60, 10, 'navaneetha']

# %%
l1.append(10)

# %%
l1
# Out:
# [100, 20, 30, 40, 50, 60, 10, 'navaneetha', 10]

# %%
l1.index(10)
# Out:
# 6

# %%
l1
# Out:
# [100, 20, 30, 40, 50, 60, 10, 'navaneetha', 10]

# %%
l1.insert(2,25)

# %%
l1
# Out:
# [100, 20, 25, 30, 40, 50, 60, 10, 'navaneetha', 10]

# %%
l1.pop()
# Out:
# 10

# %%
l1
# Out:
# [100, 20, 25, 30, 40, 50, 60, 10, 'navaneetha']

# %%
l1.pop()
# Out:
# 'navaneetha'

# %%
l1
# Out:
# [100, 20, 25, 30, 40, 50, 60, 10]

# %%
l.pop()
# Out:
# 'navaneetha'

# %%
l
# Out:
# [34, 5.3, 'navaneetha', (1+2j), True, 100, 20, 30, 40, 50, 60, 10]

# %%
l.pop(2)
# Out:
# 'navaneetha'

# %%
l
# Out:
# [34, 5.3, (1+2j), True, 100, 20, 30, 40, 50, 60, 10]

# %%
l.pop(3)
# Out:
# True

# %%
l
# Out:
# [34, 5.3, (1+2j), 100, 20, 30, 40, 50, 60, 10]

# %%
l.remove(100)

# %%
l
# Out:
# [34, 5.3, 20, 30, 40, 50, 60, 10]

# %%
l.reverse()

# %%
l
# Out:
# [10, 60, 50, 40, 30, 20, 5.3, 34]

# %%
l.reverse()

# %%
l
# Out:
# [34, 5.3, 20, 30, 40, 50, 60, 10]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [34, 5.3, 20, 30, 40, 50, 60, 10]
# [100, 20, 25, 30, 40, 50, 60, 10]
# [34, 5.3, 'navaneetha', (1+2j), True]

# %%
l.sort()

# %%
l
# Out:
# [5.3, 10, 20, 30, 34, 40, 50, 60]

# %%
l2.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 l2.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
l1.sort()

# %%
l1
# Out:
# [10, 20, 25, 30, 40, 50, 60, 100]

# %%
l1.sort(reverse=True)

# %%
l1
# Out:
# [100, 60, 50, 40, 30, 25, 20, 10]

# %%
l3=[3,1,2]

# %%
l3
# Out:
# [3, 1, 2]

# %%
l3.sort()

# %%
l3
# Out:
# [1, 2, 3]

# %%
l3.sort(reverse=True)

# %%
l3
# Out:
# [3, 2, 1]

# %%
l2
# Out:
# [34, 5.3, 'navaneetha', (1+2j), True]

# %%
l2[2]
# Out:
# 'navaneetha'

# %%
l2[2][0]
# Out:
# 'n'

# %%
print(l2[2][0])
print(l2[2][1])
print(l2[2][2])
print(l2[2][3])
print(l2[2][4])
print(l2[2][5])
print(l2[2][6])
print(l2[2][7])
print(l2[2][8])
print(l2[2][9])
print(l2[2][10])
# Out:
# n
# a
# v
# a
# n
# e
# e
# t
# h
# a
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[74], line 11
#       9 print(l2[2][8])
#      10 print(l2[2][9])
# ---> 11 print(l2[2][10])
#
# IndexError: string index out of range

# %%
print(l2[2][0])
print(l2[2][1])
print(l2[2][2])
print(l2[2][3])
print(l2[2][4])
print(l2[2][5])
print(l2[2][6])
print(l2[2][7])
print(l2[2][8])
print(l2[2][9])
# Out:
# n
# a
# v
# a
# n
# e
# e
# t
# h
# a

# %%
l
# Out:
# [5.3, 10, 20, 30, 34, 40, 50, 60]

# %%
for i in l:
    print(i)
# Out:
# 5.3
# 10
# 20
# 30
# 34
# 40
# 50
# 60

# %%
for i in enumerate(l):
    print(i)
# Out:
# (0, 5.3)
# (1, 10)
# (2, 20)
# (3, 30)
# (4, 34)
# (5, 40)
# (6, 50)
# (7, 60)

# %%
l1
# Out:
# [100, 60, 50, 40, 30, 25, 20, 10]

# %%
all(l1)
# Out:
# True

# %%
any(l1)
# Out:
# True

# %%
l1.append(0)

# %%
l1
# Out:
# [100, 60, 50, 40, 30, 25, 20, 10, 0]

# %%
all(l1)
# Out:
# False

# %%
any(l1)
# Out:
# True

# %%
l4=[]
l4
# Out:
# []

# %%
all(l4)
# Out:
# True

# %%
l4.append(0)

# %%
l4
# Out:
# [0]

# %%
all(l4)
# Out:
# False

# %%
any(l4)
# Out:
# False

# %%
l4.append(10)

# %%
l4
# Out:
# [0, 10]

# %%
any(l4)
# Out:
# True

# %%
all(l4)
# Out:
# False

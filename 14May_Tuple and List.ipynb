# %% [markdown]
# 14May_Tuple

# %%
t=()

# %%
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t1=(10,20,30)

# %%
t1
# Out:
# (10, 20, 30)

# %%
t2=(10,2.3,'nit',True,(1+2j))

# %%
t2
# Out:
# (10, 2.3, 'nit', True, (1+2j))

# %%
print(t)
print(t1)
print(t2)
# Out:
# ()
# (10, 20, 30)
# (10, 2.3, 'nit', True, (1+2j))

# %%
t1
# Out:
# (10, 20, 30)

# %%
t.count(10)
# Out:
# 0

# %%
t1.count(10)
# Out:
# 1

# %%
t1
# Out:
# (10, 20, 30)

# %%
t1.index(20)
# Out:
# 1

# %%
t1.append(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 t1.append(10)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t1
# Out:
# (10, 20, 30)

# %%
t1
# Out:
# (10, 20, 30)

# %%
t1.index(10)
# Out:
# 0

# %%
t1.index(20)
# Out:
# 1

# %%
t1.index(30)
# Out:
# 2

# %%
t1(20)=200
# Out:
#   Cell In[28], line 1
#     t1(20)=200
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
hdfc = ('navaneetha', 123456, 'cizps') 
hdfc
# Out:
# ('navaneetha', 123456, 'cizps')

# %%
hdfc[1]=3456
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 hdfc[1]=3456
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1
# Out:
# (10, 20, 30)

# %%
t1.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 t1.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
t1*3
# Out:
# (10, 20, 30, 10, 20, 30, 10, 20, 30)

# %%
t3=t1*3

# %%
t3
# Out:
# (10, 20, 30, 10, 20, 30, 10, 20, 30)

# %% [markdown]
# #Set

# %%
s={}

# %%
s
# Out:
# {}

# %%
type(s)
# Out:
# dict

# %%
s1={100,4,10,3,90,20,50}

# %%
s1
# Out:
# {3, 4, 10, 20, 50, 90, 100}

# %%
type(s1)
# Out:
# set

# %%
s2={3,1+2j,True,3.4}

# %%
s2
# Out:
# {(1+2j), 3, 3.4, True}

# %%
print(s)
print(s1)
print(s2)
# Out:
# {}
# {50, 3, 100, 4, 20, 90, 10}
# {3, True, 3.4, (1+2j)}

# %%
print(type(s))
print(type(s1))
print(type(s2))
# Out:
# <class 'dict'>
# <class 'set'>
# <class 'set'>

# %%
s1
# Out:
# {3, 4, 10, 20, 50, 90, 100}

# %%
s1.add(25)

# %%
s1
# Out:
# {3, 4, 10, 20, 25, 50, 90, 100}

# %%
s1.add(200,300)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 s1.add(200,300)
#
# TypeError: set.add() takes exactly one argument (2 given)

# %%
s3=s1.copy()

# %%
s3
# Out:
# {3, 4, 10, 20, 25, 50, 90, 100}

# %%
print(s1)
print(s2)
print(s3)
# Out:
# {50, 3, 100, 4, 20, 90, 25, 10}
# {3, True, 3.4, (1+2j)}
# {3, 100, 4, 10, 50, 20, 25, 90}

# %%
s3.clear()

# %%
s3
# Out:
# set()

# %%
s1
# Out:
# {3, 4, 10, 20, 25, 50, 90, 100}

# %%
s1(0)     #Indexing and Slicing not allowed in set function
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 s1(0)     #Indexing and Slicing not allowed in set function
#
# TypeError: 'set' object is not callable

# %%
s1
# Out:
# {3, 4, 10, 20, 25, 50, 90, 100}

# %%
s1[:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 s1[:]
#
# TypeError: 'set' object is not subscriptable

# %%
s1
# Out:
# {3, 4, 10, 20, 25, 50, 90, 100}

# %%
s1.pop()  #it will remove the random value
# Out:
# 50

# %%
s1.pop(2) #it wont work because set does not allow indexing and slicing
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 s1.pop(2)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
s1
# Out:
# {3, 4, 10, 20, 25, 90, 100}

# %%
s1.discard(1000)   #Discard function does not throw error even not in the list

# %%
s1
# Out:
# {3, 4, 10, 20, 25, 90, 100}

# %%
s1.remove(1000)   #remove function will throw the error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 s1.remove(1000)
#
# KeyError: 1000

# %%
s1.discard(4)

# %%
s1
# Out:
# {3, 10, 20, 25, 90, 100}

# %%
s1.add(10)

# %%
s1     #duplicates not allowed in set but allowed in list and tuple
# Out:
# {3, 10, 20, 25, 90, 100}
